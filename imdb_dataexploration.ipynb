# %% [markdown]
# # Exploratory Data Analysis for IMDB Data #

# %%
# !pwd
# Out:
# /Users/italo/Desktop/Course Material/section01/Module1 Project/2020-movie-analysis

# %%
import pandas as pd
names = pd.read_csv('Data/imdb.name.basics.csv')
names.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
names.tail()
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#            primary_profession     known_for_titles
# 606643                actress                  NaN
# 606644                actress  tt9090932,tt8737130
# 606645                actress  tt8734436,tt9615610
# 606646               producer                  NaN
# 606647  director,actor,writer            tt8743182

# %%
names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %% [markdown]
# ***name features the names of different people in the industry and list their primary profession in the industry (actress, director, producer, etc.) as well as the prominent titles they are known for given as an identifier (primary key for another data set?). Also list, birth year and death year if applicable.***

# %%
title_akas = pd.read_csv('Data/imdb.title.akas.csv')
title_akas.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
title_akas.tail()
# Out:
#          title_id  ordering               title region language        types  \
# 331698  tt9827784         2  Sayonara kuchibiru    NaN      NaN     original
# 331699  tt9827784         3       Farewell Song    XWW       en  imdbDisplay
# 331700  tt9880178         1         La atención    NaN      NaN     original
# 331701  tt9880178         2         La atención     ES      NaN          NaN
# 331702  tt9880178         3       The Attention    XWW       en  imdbDisplay
#
#        attributes  is_original_title
# 331698        NaN                1.0
# 331699        NaN                0.0
# 331700        NaN                1.0
# 331701        NaN                0.0
# 331702        NaN                0.0

# %%
title_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
title_akas.region.value_counts()
# Out:
# US      51490
# XWW     18467
# RU      13817
# DE      11634
# FR      10990
#         ...
# LY          1
# NC          1
# WF          1
# LS          1
# CSHH        1
# Name: region, Length: 213, dtype: int64

# %%
title_akas.language.value_counts()
# Out:
# en     22895
# tr      3847
# bg      3609
# fr      3576
# he      2680
#        ...
# wo         1
# xh         1
# ka         1
# fro        1
# ku         1
# Name: language, Length: 76, dtype: int64

# %%
title_akas[title_akas.language == 'en']
# Out:
#           title_id  ordering                        title region language  \
# 87      tt10027708         2                    Miguelito    XWW       en
# 89      tt10027708         4                    Miguelito     AU       en
# 95       tt1014759        10  Alice Dar Sarzamin E Ajayeb     IE       en
# 127      tt1014759         3          Alice in Wonderland     JP       en
# 142     tt10225354         3               Returning Home    XWW       en
# ...            ...       ...                          ...    ...      ...
# 331679   tt9644084         3                   The Breath    XWW       en
# 331680   tt9654246         1    The Wild Man of the North    XWW       en
# 331683   tt9657946         1                       Homing    XWW       en
# 331699   tt9827784         3                Farewell Song    XWW       en
# 331702   tt9880178         3                The Attention    XWW       en
#
#               types attributes  is_original_title
# ...

# %%
title_akas[title_akas.region == 'US']
# Out:
#          title_id  ordering                                        title  \
# 12      tt0369610        21                            Jurassic World 3D
# 20      tt0369610        29                               Jurassic World
# 21      tt0369610         2                                     Ebb Tide
# 28      tt0369610        36                             Jurassic Park IV
# 37      tt0369610        44                              Jurassic Park 4
# ...           ...       ...                                          ...
# 331645  tt9310460         6  Coconut the Little Dragon 2 Into the Jungle
# 331654  tt9358044         2                                  Hail Satan?
# 331673  tt9562694         5                                Alien Warfare
# 331686  tt9705860         1          Dusan Vukotic Croatian Oscar Winner
# 331694  tt9755806         1                                    Big Shark
#
#        region language        types                  attributes  \
# ...

# %%
title_akas.types.value_counts()
# Out:
# imdbDisplay         100461
# original             44700
# working               8680
# alternative           6564
# festival              3307
# dvd                   2995
# tv                    1617
# video                  121
# dvdimdbDisplay          1
# festivalworking         1
# Name: types, dtype: int64

# %% [markdown]
# ***title_akas list the title of movies as they appear in different langauges and different regions. localized versions***

# %%
title_basics = pd.read_csv('Data/imdb.title.basics.csv')
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
title_basics.tail()
# Out:
#            tconst                                primary_title  \
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 146139            123.0        Drama
# 146140              NaN  Documentary
# 146141              NaN       Comedy
# 146142            116.0          NaN
# ...

# %% [markdown]
# ***title_basics lists the primary title of a movie. Primary title is the title of the film as it was advertised/promoted. It list the original title (in the original language). List year it was release, run_time, and up to three genres related to the movie***

# %%
title_basics[title_basics.start_year == 2019]
# Out:
#            tconst                    primary_title       original_title  \
# 1       tt0066787  One Day Before the Rainy Season      Ashad Ka Ek Din
# 26      tt0263814                         On kadin             On kadin
# 31      tt0285423                         Abolição             Abolição
# 68      tt0385887              Motherless Brooklyn  Motherless Brooklyn
# 107     tt0437086              Alita: Battle Angel  Alita: Battle Angel
# ...           ...                              ...                  ...
# 146134  tt9916160                       Drømmeland           Drømmeland
# 146135  tt9916170                    The Rehearsal             O Ensaio
# 146137  tt9916190                        Safeguard            Safeguard
# 146138  tt9916428              The Secret of China  The Secret of China
# 146139  tt9916538              Kuambil Lagi Hatiku  Kuambil Lagi Hatiku
#
#         start_year  runtime_minutes                   genres
# ...

# %%
# write function that returns true if Sci-Fi is a genre for a movie
example = title_basics.iloc[107].genres
'Sci-Fi' in example
# Out:
# True

# %%
# write funciton for entire column

# %%
crew = pd.read_csv('Data/imdb.title.crew.csv')
crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
crew.shape
# Out:
# (146144, 3)

# %% [markdown]
# ***crew list director(s) and writer(s) for a film. It is all reference using the unique id identifiers. For movie and names.***

# %%
principals = pd.read_csv('Data/imdb.title.principals.csv')
principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
principals.category.unique()
# Out:
# array(['actor', 'director', 'producer', 'editor', 'actress', 'composer',
#        'cinematographer', 'writer', 'self', 'production_designer',
#        'archive_footage', 'archive_sound'], dtype=object)

# %%
principals.tconst.nunique()
# Out:
# 143454

# %% [markdown]
# ***principals list the principal cast and crew for a given movie (actor, directors, producers, etc.). Information can be found by access title's unique id as well as person's unique id)***

# %%
title_basics[title_basics.tconst == 'tt0111414']
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  genres
# 5  tt0111414   A Thin Life    A Thin Life        2018             75.0  Comedy

# %%
names[names.nconst == 'nm0246005']
# Out:
#           nconst  primary_name  birth_year  death_year primary_profession  \
# 45162  nm0246005  Tommy Dysart         NaN         NaN              actor
#
#                               known_for_titles
# 45162  tt0093120,tt0076974,tt0084296,tt0077064

# %%
ratings = pd.read_csv('Data/imdb.title.ratings.csv')
ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
title_basics[title_basics.tconst == 'tt1043726']
# Out:
#          tconst           primary_title          original_title  start_year  \
# 4825  tt1043726  The Legend of Hercules  The Legend of Hercules        2014
#
#       runtime_minutes                    genres
# 4825             99.0  Action,Adventure,Fantasy

# %% [markdown]
# ***ratings contains the average rating for a given title based on user reviews on imdb. As well as the number of votes used to get that rating***

# %%
ratings.sort_values('averagerating', ascending = False)
# Out:
#           tconst  averagerating  numvotes
# 27644  tt8730716           10.0         5
# 8992   tt1770682           10.0         5
# 26153  tt2632430           10.0         5
# 65033  tt9715646           10.0        20
# 57679  tt5344358           10.0         6
# ...          ...            ...       ...
# 50971  tt6017238            1.0        21
# 32440  tt2087999            1.0         7
# 36456  tt1896768            1.0        21
# 54856  tt1976600            1.0       436
# 39248  tt8654080            1.0        21
#
# [73856 rows x 3 columns]

# %%
title_basics[title_basics.tconst == 'tt8730716']
# Out:
#            tconst                  primary_title  \
# 136750  tt8730716  Pick It Up! - Ska in the '90s
#
#                        original_title  start_year  runtime_minutes  \
# 136750  Pick It Up! - Ska in the '90s        2019             99.0
#
#              genres
# 136750  Documentary

# %% [markdown]
# ## rename columns for easier manipulation ##

# %%
new_names = {'nconst' : 'name_id', 'tconst' : 'title_id'}

# %%
names.rename(new_names, axis = 1, inplace = True)
names.head(2)
# Out:
#      name_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
#
#                            primary_profession  \
# 0   miscellaneous,production_manager,producer
# 1  composer,music_department,sound_department
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940

# %%
title_akas.rename(new_names, axis = 1, inplace = True)
title_akas.head(2)
# Out:
#     title_id  ordering              title region language        types  \
# 0  tt0369610        10      Джурасик свят     BG       bg          NaN
# 1  tt0369610        11  Jurashikku warudo     JP      NaN  imdbDisplay
#
#   attributes  is_original_title
# 0        NaN                0.0
# 1        NaN                0.0

# %%
title_basics.rename(new_names, axis = 1, inplace = True)
title_basics.head(2)
# Out:
#     title_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres
# 0            175.0  Action,Crime,Drama
# 1            114.0     Biography,Drama

# %%
crew.rename(new_names, axis = 1, inplace = True)
crew.head(2)
# Out:
#     title_id  directors              writers
# 0  tt0285252  nm0899854            nm0899854
# 1  tt0438973        NaN  nm0175726,nm1802864

# %%
principals.rename(new_names, axis = 1, inplace = True)
principals.head(2)
# Out:
#     title_id  ordering    name_id  category  job   characters
# 0  tt0111414         1  nm0246005     actor  NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director  NaN          NaN

# %%
ratings.rename(new_names, axis = 1, inplace = True)
ratings.head(2)
# Out:
#      title_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559

# %%
title_basics.head(2)
# Out:
#     title_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres
# 0            175.0  Action,Crime,Drama
# 1            114.0     Biography,Drama

# %%
ratings.head(2)
# Out:
#      title_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559

# %%
title_basics.set_index('title_id', inplace = True)
ratings.set_index('title_id', inplace = True)

# %%
basics_and_ratings = title_basics.join(ratings, how = 'left')

# %%
basics_and_ratings.drop('index', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-0f189db1d187> in <module>
# ----> 1 basics_and_ratings.drop('index', axis = 1, inplace = True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
basics_and_ratings.head()
# Out:
#                              primary_title              original_title  \
# title_id
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres  averagerating  \
# title_id
# tt0063540        2013            175.0    Action,Crime,Drama            7.0
# tt0066787        2019            114.0       Biography,Drama            7.2
# tt0069049        2018            122.0                 Drama            6.9
# tt0069204        2018              NaN          Comedy,Drama            6.1
# tt0100275        2017             80.0  Comedy,Drama,Fantasy            6.5
#
#            numvotes
# title_id
# tt0063540      77.0
# ...

# %% [markdown]
# ### List of DataFrames ###
#
# name = name of people in the industry and notable works
#
# basics_and_ratings = basic info of film, including title(s), runtime, year released, genre, average rating, number of votes
#
# title_akas = lists movie titles in different regions on their localizations
#
# crew = writer(s) and director(s) for different movies
#
# principals = principal crew/cast for a movie

# %%
print(names.shape)
print(basics_and_ratings.shape)
print(title_akas.shape)
print(crew.shape)
print(principals.shape)
# Out:
# (606648, 6)
# (146144, 7)
# (331703, 8)
# (146144, 3)
# (1028186, 6)

# %%
#alternate basics_and_ratings:
basics_and_ratings2 = pd.merge(title_basics, ratings, on = 'title_id')
basics_and_ratings2.isnull().any()
# Out:
# title_id           False
# primary_title      False
# original_title     False
# start_year         False
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# dtype: bool

# %%
basics_and_ratings.sort_values(by = 'start_year', inplace = True)
basics_and_ratings.head()
# Out:
#                      primary_title           original_title  start_year  \
# title_id
# tt1566491  Brainiacs in La La Land  Brainiacs in La La Land        2010
# tt1731226                  Respira                  Respira        2010
# tt1731229               The Depths               The Depths        2010
# tt1731230                 Turquaze                 Turquaze        2010
# tt1731655  Ten Days: Terese Taylor  Ten Days: Terese Taylor        2010
#
#            runtime_minutes             genres  averagerating  numvotes
# title_id
# tt1566491              NaN             Comedy            NaN       NaN
# tt1731226             65.0        Documentary            NaN       NaN
# tt1731229            121.0              Drama            4.0     121.0
# tt1731230             96.0              Drama            6.1     345.0
# tt1731655             77.0  Documentary,Music            NaN       NaN

# %%
basics_and_ratings2.sort_values(by = 'start_year', inplace  = True)
basics_and_ratings2.head()
# Out:
#         title_id                               primary_title  \
# 5553   tt1612608                                 The Italian
# 49321  tt4874854  The Legend of Zelda: The Triforce Prophecy
# 8206   tt1718842                          Nakalnya anak muda
# 6276   tt1645134                                  Sandcastle
# 6274   tt1645129                                     Planzet
#
#                                    original_title  start_year  \
# 5553                                    L'Italien        2010
# 49321  The Legend of Zelda: The Triforce Prophecy        2010
# 8206                           Nakalnya anak muda        2010
# 6276                                   Sandcastle        2010
# 6274                                   Puranzetto        2010
#
#        runtime_minutes                     genres  averagerating  numvotes
# 5553             102.0               Comedy,Drama            5.8      1360
# ...

# %%
basics_and_ratings.to_csv('imdb.basics_and_ratings_nulls.csv', index = False)
basics_and_ratings2.to_csv('imdb.basics_and_ratings_nonulls.csv', index = False)
